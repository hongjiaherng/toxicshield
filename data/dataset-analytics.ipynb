# %% [markdown]
# # Prerequisite

# %%
# !pip3 install kagglehub[pandas-datasets]
# !pip3 install nltk

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA (Toxic Tweets Dataset)

# %%
# Load the specific CSV file directly into a DataFrame
df01 = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "ashwiniyer176/toxic-tweets-dataset",
    "FinalBalancedDataset.csv"
)

# %%
print("--- Dataset Information ---")
print(df01.info())
print("\n--- Summary Statistics ---")
print(df01.describe())

# %% [markdown]
# ## Visualisation

# %%
# dataframe of Toxic Tweets Dataset
mock_df = df01

plt.figure(figsize=(8, 6))
sns.countplot(x='Toxicity', data=mock_df, palette='magma')
plt.title('Frequency of Toxic (1) vs. Non-Toxic (0) Tweets Comments')
plt.xlabel('Toxicity')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('toxicity_histogram.png')
print(mock_df.describe(include='all'))

# %% [markdown]
# # EDA (Social Media Toxic Comment Dataset)

# %%
# Load the latest version
df02 = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "miadul/toxic-comments-detection-dataset",
  "toxic_comments_50000.csv",
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

# %%
print("--- Dataset Information ---")
print(df02.info())
print("\n--- Summary Statistics ---")
print(df02.describe())

# %% [markdown]
# ## Visualisation

# %%
mock_df_02 = df02
plt.figure(figsize=(8, 6))

# Use value_counts unique frequency
sns.countplot(
    x='label', 
    data=mock_df_02, 
    palette='magma', 
    order=mock_df_02['label'].value_counts().index
)

plt.title('Frequency of Unique Toxicity Labels')
plt.xlabel('Toxicity Category')
plt.ylabel('Count of Unique Occurrences')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.savefig('toxicity_histogram_02.png')
plt.show()

# Display summary statistics
print(mock_df_02['label'].describe())
